# %% [markdown]
# ### Yelp Dataset
# Dataset prep

# %% [markdown]
# Generate an API key at kaggle.com (if you haven't already) and save it.

# %%
# !pip install -q kagglehub

# %%
import kagglehub
print(kagglehub.__version__)
# Out:
# 1.0.1

# %%
kagglehub.dataset_download("yelp-dataset/yelp-dataset", path="yelp_academic_dataset_business.json", output_dir="../data/raw")
kagglehub.dataset_download("yelp-dataset/yelp-dataset", path="yelp_academic_dataset_checkin.json", output_dir="../data/raw")
kagglehub.dataset_download("yelp-dataset/yelp-dataset", path = "yelp_academic_dataset_tip.json", output_dir="../data/raw")
# Out:
# ...
# 100%|██████████| 20.8M/20.8M [00:01<00:00, 21.2MB/s]
# Extracting zip of yelp_academic_dataset_business.json...
# ...
# 100%|██████████| 79.2M/79.2M [00:03<00:00, 21.5MB/s]
# Extracting zip of yelp_academic_dataset_checkin.json...
# ...
# 100%|██████████| 69.5M/69.5M [00:03<00:00, 24.0MB/s]
# Extracting zip of yelp_academic_dataset_tip.json...
# '../data/raw/yelp_academic_dataset_tip.json'
